# %%
import cv2
from ultralytics import YOLO

# Function to convert a bounding box to a circle
def box_to_circle(x1, y1, x2, y2):
    center = (int(x1 + (x2 - x1) / 2), int(y1 + (y2 - y1) / 2))
    radius = int(min(x2 - x1, y2 - y1) / 2)
    return center, radius

# Load the YOLO model
model = YOLO('G:/yolo_model/runs/detect/train/weights/best.pt')

# Load the image
image_path = r"G:\yolo_model\image_test.png"
image = cv2.imread(image_path)

# Perform prediction
results = model(image_path)

# Extract bounding boxes and labels
if results:
    for result in results:
        boxes = result.boxes  # Access boxes from the result
        for box in boxes:
            x1, y1, x2, y2 = box.xyxy[0].cpu().numpy()  # Get coordinates
            center, radius = box_to_circle(x1, y1, x2, y2)
            cv2.circle(image, center, radius, (0, 255, 0), 2)  # Draw circle

# Save and display the modified image
output_path = "G:/yolo_model/predicted_circle.png"
cv2.imwrite(output_path, image)
cv2.imshow("Detected Circles", image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# image 1/1 G:\yolo_model\image_test.png: 640x640 13 Craters, 6.0ms
# Speed: 3.0ms preprocess, 6.0ms inference, 64.6ms postprocess per image at shape (1, 3, 640, 640)

# %%
import cv2
from ultralytics import YOLO

# Function to convert a bounding box to a circle
def box_to_circle(x1, y1, x2, y2):
    center = (int(x1 + (x2 - x1) / 2), int(y1 + (y2 - y1) / 2))
    radius = int(min(x2 - x1, y2 - y1) / 2)
    return center, radius

# Load the YOLO model
model = YOLO('G:/yolo_model/runs/detect/train/weights/best.pt')

# Load the image
image_path = r"G:\yolo_model\image_test.png"
image = cv2.imread(image_path)

# Perform prediction
results = model(image_path)

# Extract bounding boxes and labels
if results:
    for result in results:
        boxes = result.boxes  # Access boxes from the result
        for box in boxes:
            x1, y1, x2, y2 = box.xyxy[0].cpu().numpy()  # Get coordinates
            label = box.cls[0].item()  # Get label index
            confidence = box.conf[0].item()  # Get confidence score
            label_name = model.names[int(label)]  # Get label name
            label_text = f"{label_name} {confidence:.2f}"  # Prepare label text
            center, radius = box_to_circle(x1, y1, x2, y2)
            cv2.circle(image, center, radius, (0, 255, 0), 2)  # Draw circle
            cv2.putText(image, label_text, (center[0] - radius, center[1] - radius - 10),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)  # Draw label

# Save and display the modified image
output_path = "G:/yolo_model/predicted_circle_with_labels.png"
cv2.imwrite(output_path, image)
cv2.imshow("Detected Circles with Labels", image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# image 1/1 G:\yolo_model\image_test.png: 640x640 13 Craters, 26.6ms
# Speed: 4.0ms preprocess, 26.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)

# %%
import cv2
from ultralytics import YOLO

# Function to convert a bounding box to a circle
def box_to_circle(x1, y1, x2, y2):
    center = (int(x1 + (x2 - x1) / 2), int(y1 + (y2 - y1) / 2))
    radius = int(min(x2 - x1, y2 - y1) / 2)
    return center, radius

# Load the YOLO model
model = YOLO('G:/yolo_model/runs/detect/train/weights/best.pt')

# Load the image
image_path = r"G:\yolo_model\image_test.png"
image = cv2.imread(image_path)

# Perform prediction
results = model(image_path)

# Extract bounding boxes and labels
if results:
    for result in results:
        boxes = result.boxes  # Access boxes from the result
        for box in boxes:
            x1, y1, x2, y2 = box.xyxy[0].cpu().numpy()  # Get coordinates
            label = box.cls[0].item()  # Get label index
            confidence = box.conf[0].item()  # Get confidence score
            label_name = model.names[int(label)]  # Get label name
            label_text = f"{label_name} {confidence:.2f}"  # Prepare label text
            center, radius = box_to_circle(x1, y1, x2, y2)
            cv2.circle(image, center, radius, (255, 0, 0), 2)  # Draw circle in blue

            # Get text size
            (text_width, text_height), baseline = cv2.getTextSize(label_text, cv2.FONT_HERSHEY_DUPLEX , 0.5, 2)

            # Draw background rectangle
            cv2.rectangle(image, (center[0] - radius, center[1] - radius - text_height - 10),
                          (center[0] - radius + text_width, center[1] - radius), (255, 0, 0), -1)

            # Draw text
            cv2.putText(image, label_text, (center[0] - radius, center[1] - radius - 5),
                        cv2.FONT_HERSHEY_DUPLEX, 0.5, (255, 255, 255), 2)  # White text

# Save and display the modified image
output_path = "G:/yolo_model/predicted_circle_with_labels.png"
cv2.imwrite(output_path, image)
cv2.imshow("Detected Circles with Labels", image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# image 1/1 G:\yolo_model\image_test.png: 640x640 13 Craters, 24.5ms
# Speed: 7.0ms preprocess, 24.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 25
#      23 boxes = result.boxes  # Access boxes from the result
#      24 for box in boxes:
# ---> 25     x1, y1, x2, y2 = box.xyxy[0].numpy()  # Get coordinates
#      26     label = box.cls[0].item()  # Get label index
#      27     confidence = box.conf[0].item()  # Get confidence score
#
# TypeError: can't convert cuda:0 device type tensor to numpy. Use Tensor.cpu() to copy the tensor to host memory first.

# %%
import cv2
from ultralytics import YOLO

# Function to convert a bounding box to a circle
def box_to_circle(x1, y1, x2, y2):
    center = (int(x1 + (x2 - x1) / 2), int(y1 + (y2 - y1) / 2))
    radius = int(min(x2 - x1, y2 - y1) / 2)
    return center, radius

# Load the YOLO model
model = YOLO('G:/yolo_model/runs/detect/train/weights/best.pt')

# Load the image
image_path = r"G:\yolo_model\image_test.png"
image = cv2.imread(image_path)

# Perform prediction
results = model(image_path)

# Extract bounding boxes and labels
detections = results[0].boxes

# Draw circles on the image
for box in detections:
    x1, y1, x2, y2 = box.xyxy[0]
    center, radius = box_to_circle(x1, y1, x2, y2)
    cv2.circle(image, center, radius, (255, 0, 0), 2)  # Draw blue circle

    # Calculate diameter in pixels and convert to meters
    diameter_pixels = radius * 2
    diameter_meters = diameter_pixels * 0.32  # Convert to meters using resolution

    # Draw label background
    label = f'{diameter_meters:.2f} m'
    (w, h), _ = cv2.getTextSize(label, cv2.FONT_HERSHEY_SIMPLEX, 0.6, 1)
    cv2.rectangle(image, (center[0] - w // 2, center[1] - radius - 20), (center[0] + w // 2, center[1] - radius - 20 + h), (255, 0, 0), -1)

    # Draw label text
    cv2.putText(image, label, (center[0] - w // 2, center[1] - radius - 5), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255, 255, 255), 1, cv2.LINE_AA)

# Save and display the modified image
output_path = "G:/yolo_model/predicted_circle.png"
cv2.imwrite(output_path, image)
cv2.imshow("Detected Circles", image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# image 1/1 G:\yolo_model\image_test.png: 640x640 13 Craters, 24.0ms
# Speed: 9.0ms preprocess, 24.0ms inference, 164.6ms postprocess per image at shape (1, 3, 640, 640)

# %%
import cv2
from ultralytics import YOLO

# Function to convert a bounding box to a circle
def box_to_circle(x1, y1, x2, y2):
    center = (int(x1 + (x2 - x1) / 2), int(y1 + (y2 - y1) / 2))
    radius = int(min(x2 - x1, y2 - y1) / 2)
    return center, radius

# Load the YOLO model
model = YOLO('G:/yolo_model/runs/detect/train/weights/best.pt')

# Load the image
image_path = r"G:\yolo_model\image_test.png"
image = cv2.imread(image_path)

# Perform prediction
results = model(image_path)

# Extract bounding boxes and labels
detections = results[0].boxes

# Draw circles and labels on the image
for box in detections:
    x1, y1, x2, y2 = box.xyxy[0]
    center, radius = box_to_circle(x1, y1, x2, y2)
    cv2.circle(image, center, radius, (255, 0, 0), 2)  # Draw blue circle

    # Calculate diameter in pixels and convert to meters
    diameter_pixels = radius * 2
    diameter_meters = diameter_pixels * 0.32  # Convert to meters using resolution

    # Draw label background
    label = f'{diameter_meters:.2f} m'
    (w, h), _ = cv2.getTextSize(label, cv2.FONT_HERSHEY_SIMPLEX, 0.6, 1)
    cv2.rectangle(image, (center[0] - w // 2, center[1] - radius - 20), 
                  (center[0] + w // 2, center[1] - radius - 20 + h), (255, 0, 0), -1)

    # Draw label text
    cv2.putText(image, label, (center[0] - w // 2, center[1] - radius - 5), 
                cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255, 255, 255), 1, cv2.LINE_AA)

# Save and display the modified image
output_path = "G:/yolo_model/predicted_circle.png"
cv2.imwrite(output_path, image)
cv2.imshow("Detected Circles", image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# image 1/1 G:\yolo_model\image_test.png: 640x640 13 Craters, 51.8ms
# Speed: 7.9ms preprocess, 51.8ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
